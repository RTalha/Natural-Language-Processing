# %%
import re

# %%
text="the film titanic was released in 1998"

# %%
"""
Reimplementation of the
`Porter stemming algorithm <http://tartarus.org/~martin/PorterStemmer/>`_
in Python.

In my quick tests, this implementation about 3.5 times faster than the
seriously weird Python linked from the official page.
"""

import re

# Suffix replacement lists
count=0
count1=0
_step2list = {
              "ational": "ate",
              "tional": "tion",
              "enci": "ence",
              "anci": "ance",
              "izer": "ize",
              "bli": "ble",
              "alli": "al",
              "entli": "ent",
              "eli": "e",
              "ousli": "ous",
              "ization": "ize",
              "ation": "ate",
              "ator": "ate",
              "alism": "al",
              "iveness": "ive",
              "fulness": "ful",
              "ousness": "ous",
              "aliti": "al",
              "iviti": "ive",
              "biliti": "ble",
              "logi": "log",          
              }

_step3list = {
              "icate": "ic",
              "ative": "",
              "alize": "al",
              "iciti": "ic",
              "ical": "ic",
              "ful": "",
              "ness": "",          
              }


_cons = "[^aeiou]"
_vowel = "[aeiouy]"
_cons_seq = "[^aeiouy]+"
_vowel_seq = "[aeiou]+"

# m > 0
_mgr0 = re.compile("^(" + _cons_seq + ")?" + _vowel_seq + _cons_seq)
# m == 0
_meq1 = re.compile("^(" + _cons_seq + ")?" + _vowel_seq + _cons_seq + "(" + _vowel_seq + ")?$")
# m > 1
_mgr1 = re.compile("^(" + _cons_seq + ")?" + _vowel_seq + _cons_seq + _vowel_seq + _cons_seq)
# vowel in stem
_s_v = re.compile("^(" + _cons_seq + ")?" + _vowel)
# ???
_c_v = re.compile("^" + _cons_seq + _vowel + "[^aeiouwxy]$")

# Patterns used in the rules

_ed_ing = re.compile("^(.*)(ed|ing)$")
_at_bl_iz = re.compile("(at|bl|iz)$")
_step1b = re.compile("([^aeiouylsz])\\1$")
_step2 = re.compile("^(.+?)(ational|tional|enci|anci|izer|bli|alli|entli|eli|ousli|ization|ation|ator|alism|iveness|fulness|ousness|aliti|iviti|biliti|logi)$")
_step3 = re.compile("^(.+?)(icate|ative|alize|iciti|ical|ful|ness)$")
_step4_1 = re.compile("^(.+?)(al|ance|ence|er|ic|able|ible|ant|ement|ment|ent|ou|ism|ate|iti|ous|ive|ize)$")
_step4_2 = re.compile("^(.+?)(s|t)(ion)$")
_step5 = re.compile("^(.+?)e$")

# Stemming function

def stem(w):
    """Uses the Porter stemming algorithm to remove suffixes from English
    words.
    
    >>> stem("fundamentally")
    "fundament"
    """
    if len(w) < 3: return w
    
    first_is_y = w[0] == "y"
    if first_is_y:
        w = "Y" + w[1:]
        
    # Step 1a
    if w.endswith("s"):
        if w.endswith("sses"):
            w = w[:-2]
        elif w.endswith("ies"):
            w = w[:-2]
        elif w[-2] != "s":
            w = w[:-1]
        
    
    # Step 1b
    
    if w.endswith("eed"):
        s = w[:-3]
        if _mgr0.match(s):
            w = w[:-1]
    else:
        m = _ed_ing.match(w)
        if m:
            stem = m.group(1)
            if _s_v.match(stem):
                w = stem
                if _at_bl_iz.match(w):
                    w += "e"
                elif _step1b.match(w):
                    w = w[:-1]
                elif _c_v.match(w):
                    w += "e"
            
    # Step 1c
    
    if w.endswith("y"):
        stem = w[:-1]
        if _s_v.match(stem):
            w = stem + "i"
            
    # Step 2
    
    m = _step2.match(w)
    if m:
        stem = m.group(1)
        suffix = m.group(2)
        if _mgr0.match(stem):
            w = stem + _step2list[suffix]
            
    # Step 3
    
    m = _step3.match(w)
    if m:
        stem = m.group(1)
        suffix = m.group(2)
        if _mgr0.match(stem):
            w = stem + _step3list[suffix]

    # Step 4
    
    m = _step4_1.match(w)
    if m:
        stem = m.group(1)
        if _mgr1.match(stem):
            w = stem
    else:
        m = _step4_2.match(w)
        if m:
            stem = m.group(1) + m.group(2)
            if _mgr1.match(stem):
                w = stem
    
    # Step 5
    
    m = _step5.match(w)
    if m:
        stem = m.group(1)
        if _mgr1.match(stem) or (_meq1.match(stem) and not _c_v.match(stem)):
            w = stem
    
    if w.endswith("ll") and _mgr1.match(w):
        w = w[:-1]
    
    if first_is_y:
        w = "y" + w[1:]

    return w

if __name__ == '__main__':
    text = '''The film, '@Pulp Fiction' was ? released _ in % $ year 1994.
    Cats and ponies have meeting
    Wow very nice woman with apple
    ''' 
    str=""
    f=open("/home/rana/mypython/NLP/lecture1.txt")
    for line in f:
        ree=re.findall(r"\w+\W",line)
        count+=len(ree)
        result = re.sub(r"[,@\'?\.$%_]", "", line, flags=re.I)
        #print(len(result))
        result=re.findall(r"[a-zA-z0-9]+",result)
        #print(result)
        for i in result:
            check_stem=stem(i)
            if check_stem!=i:
                count1+=1
            str=str+" "+check_stem
        print(str)
        str=""
    print("total word was:= ",count)
    print("total word stemmed:=",count1)
    f.close()
# Out:
#  Natur Languag
#  Process NLP
#
#  Lectur 1 Introduct
#  Dr Muhammad Taimoor Khan
#  Languag
#
#  Languag is the develop acquisit mainten and us of
#  complex system of commun
#
#  The prehistor languag could onli commun the observ ie
#  have physical exist in time and space
#
#  Over a period of time the delicaci of languag allow to have
#  abstract concept and theori
#
#  Just like anyth els languag can also be us or abus How
#  Natur Human Languag
#
#  The method for human commun either spoken or written
#  It consist of the us of word in a structur and convent wai
#
#  It s a system of commun that is us by a particular
#  commun
#  There ar around 5000 to 7000 languag in the world depend
#  on the arbitrari distinct between languag and their dialect
#
#  Apart from spoken languag there ar sign languag whistl braill etc
#  Natur languag is process differ as it pass through
#  differ part of the human brain
#  Human acquir languag through social interact in earli
#  childhood and gener speak fluentli by 3 year
#
#  The us of languag is deepli entrench in human cultur
#  Therefor in addit to it strictli commun us languag
#  also ha mani social and cultur us such as signifi group
#  ident social stratif social differenti as well social
#  groom and entertain
#  Divers of Natur Languag
#
#  The complex structur of natur languag afford a much wider
#  rang of express then ani known system
#
#  It empow human to acquir the abil of a theori of other
#  mind and a share intention
#  The structur of languag evolv and diversifi over time to serv
#  specif commun and social function
#
#  Synchronic Studi of the state of a languag at ani given point in
#  histori
#
#  Diachron Differ among the state of languag over decad
#  or centuri
#  Languag Famili
#
#  The exist languag evolv and new languag ar introduc
#  New languag usual ar influenc by the domin exist
#  languag
#
#  A group of languag that descend from a common ancestor is
#  known as a languag famili
#
#  Cultur rich languag like Persian and Arabic can be observ to have
#  footprint in mani languag
#  Linguist
#
#  Scientif or systematic studi of languag It scienc in the sens
#  that it scientif studi the rule system and principl of
#  human languag
#  There ar two object of linguist or the scientif studi of
#  languag that ar
#  To establish a theori of languag and describ languag in the light of that
#  theori
#  Examin all form of languag and seek scientif understand of the
#  wai in which it is organiz serv differ need and perform function
#  CS458 Natur Languag Process
#
#  Pre Requisit
#  Prior knowledg of a Programm Languag ideal Java or
#  Python
#  Basic understand of Probabl and Statist
#  Understand of Algorithm and Data Structur
#  Class Ethic
#
#  Attendanc
#  The univers requir at least 80 attend Be in time and
#  watch your attend to avoid end semest hassl
#
#  Late Submiss of Assignment
#  Assignment after deadlin will get 10 penalti after deadlin for
#  first 3 dai and will not be mark after that Assignment will
#  have at least a week s time
#  Quizz
#  Quizz will be announc a week befor There ar no retak for
#  quizz Accommod your other plan accordingli
#
#  Project
#  The cours project would have group of two student each The idea
#  for project would be discuss later in the cours
#
#  Opportunist
#  Keep track of your effort and reward Pleas do not bother for favor
#  to stai afloat
#  Cours Descript
#
#  Natur languag process NLP address the fundament question at
#  the intersect of human languag and comput scienc It devis
#  techniqu that would help understand the basic languag structur and
#  process it for variou need Thi empow user to get insight into
#  observ human phenomena It is an interdisciplinari cours that help to
#  learn comput do us thing with human languag by mine high
#  qualiti inform from text and convert it to action knowledg It
#  mai facilit human life in differ area includ busi intellig
#  inform acquisit social behavior analysi and decis make etc
#  The cours introduc comput method that can help linguist
#  explain languag phenomena induc automat discoveri of differ
#  word sens and phrase structur The cours discuss statist and
#  probabilist method that have revolutioniz NLP in the past decad
#  Cours Objectiv
#
#
#  The student should achiev the follow object from studi thi
#  cours
#  Build model that would process a natur languag and learn about it
#  structur
#  Perform lexic syntactic and semant analysi on textual data
#  Build model that would gener natur languag
#  Build model that would identifi and extract us inform for text
#  Have understand of machin translat comprehend natur
#  languag and pragmat
#  Textbook
#
#  Speech and Languag Process by Daniel Jurafski and Jame H
#  Martin 2nd Edition 2009
#
#  Refer Book s
#  Natur Languag Process with Java Richard M Rees
#  AshishSingh Bhatia Packt publish limit 2015
#  Assessment
#
#  Assessment Quantiti Mark
#  Assignment 4 10
#  Quizz 4 10
#  Project 1 10
#  Mid Exam 1 20
#  Final Exam 1 50
#  Cours Outlin
#
#  Introduct
#  Introduct to the cours
#  Linguist and NLP
#  Basic of languag linguist and NLP
#  Regular Expression
#  Regex sequenc of charact that defin a pattern
#  Edit Distanc
#  Measur similar dissimilar among string
#  Context Free Grammar
#  Set of recurs rule us to gener pattern of string
#  Non probabilist Pars
#  Using rule to observ the syntactic structur of a languag and to pars it
#  sentenc
#  Probabilist Pars
#  Given statist model of the syntactic structur of a languag to pars
#  sentenc
#  Informat Theori
#  Sequenc of symbol to code and transmit inform
#  Languag Model
#  Probabilist model for predict next word charact sentenc
#  Part of Speech Tagg
#  Identifi the differ part of speech in a sentenc or us them to construct
#  sentenc
#  Markov Model
#  Using Markov model to simplifi the observ of probabilist model
#  Lexic and Semant
#  Word with their mean and concept
#  Machin Translat
#  Translat among natur languag through comput
#  Pragmat
#  Understand the background of a speech and respond with an action
#  Discuss
# total word was:=  968
# total word stemmed:= 438

# %%
result=re.findall(r"[a-zA-z]+",text)

# %%
print(result)
# Out:
# ['the', 'film', 'titanic', 'was', 'released', 'in']

# %%
print(result.group(0))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-0108b1a17a65> in <module>
# ----> 1 print(result.group(0))
#
# AttributeError: 'list' object has no attribute 'group'

# %%
text = "The film, '@Pulp Fiction' was ? released _ in % $ year 1994."  
result = re.sub(r"[,@\'?\.$%_]", "", text, flags=re.I)
result=re.findall(r"[a-zA-z]+",result)
print(result)
# Out:
# ['The', 'film', 'Pulp', 'Fiction', 'was', 'released', 'in', 'year']

# %%
for i in result:
    print(i)
# Out:
# The
# film
# Pulp
# Fiction
# was
# released
# in
# year
